# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dust = pd.read_csv("C:/Users/klose/Desktop/jupyter/seoul_dust(2019) 하루.csv", index_col=0)
dust
# Out:
#                                                             Address    SO2  \
# Date
# 2019-01-01 12:00  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  0.004
# 2019-01-02 12:00  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  0.004
# 2019-01-03 12:00  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  0.005
# 2019-01-04 12:00  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  0.006
# 2019-01-05 12:00  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  0.005
# ...                                                             ...    ...
# 2019-12-27 12:00  59, Gucheonmyeon-ro 42-gil, Gangdong-gu, Seoul...  0.003
# 2019-12-28 12:00  59, Gucheonmyeon-ro 42-gil, Gangdong-gu, Seoul...  0.004
# 2019-12-29 12:00  59, Gucheonmyeon-ro 42-gil, Gangdong-gu, Seoul...  0.003
# 2019-12-30 12:00  59, Gucheonmyeon-ro 42-gil, Gangdong-gu, Seoul...  0.003
# 2019-12-31 12:00  59, Gucheonmyeon-ro 42-gil, Gangdong-gu, Seoul...  0.003
#
#                     NO2     O3   CO  PM10  PM2.5
# Date
# 2019-01-01 12:00  0.020  0.025  0.6    36     24
# 2019-01-02 12:00  0.029  0.022  0.6    30     20
# 2019-01-03 12:00  0.032  0.020  0.6    39     20
# 2019-01-04 12:00  0.072  0.004  1.3    66     44
# 2019-01-05 12:00  0.024  0.023  0.6    48     26
# ...                 ...    ...  ...   ...    ...
# 2019-12-27 12:00  0.028  0.019  0.6    46     34
# 2019-12-28 12:00  0.032  0.014  0.5    43     25
# 2019-12-29 12:00  0.034  0.010  0.6    51     35
# 2019-12-30 12:00  0.053  0.003  0.8    58     42
# 2019-12-31 12:00  0.015  0.023  0.4    19     14
#
# [8708 rows x 7 columns]

# %%
dust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8708 entries, 2019-01-01 12:00 to 2019-12-31 12:00
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Address  8708 non-null   object
#  1   SO2      8708 non-null   float64
#  2   NO2      8708 non-null   float64
#  3   O3       8708 non-null   float64
#  4   CO       8708 non-null   float64
#  5   PM10     8708 non-null   int64
#  6   PM2.5    8708 non-null   int64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 544.2+ KB

# %% [markdown]
# #### PM10 미세먼지 분포

# %%
dust["PM10"].value_counts()
# Out:
# 27     177
# 32     166
# 35     166
# 24     164
# 29     159
#       ...
# 253      1
# 150      1
# 158      1
# 166      1
# 199      1
# Name: PM10, Length: 212, dtype: int64

# %%
dust.describe()
# Out:
#                SO2          NO2           O3           CO         PM10  \
# count  8708.000000  8708.000000  8708.000000  8708.000000  8708.000000
# mean     -0.007435     0.011484     0.021980     0.499518    43.286633
# std       0.108887     0.112018     0.115871     0.761336    32.849837
# min      -1.000000    -1.000000    -1.000000    -1.000000    -1.000000
# 25%       0.003000     0.013000     0.019000     0.300000    22.000000
# 50%       0.004000     0.021000     0.033000     0.400000    36.000000
# 75%       0.005000     0.031000     0.047000     0.600000    55.000000
# max       0.310000     0.087000     0.404000    29.700000   315.000000
#
#              PM2.5
# count  8708.000000
# mean     25.144006
# std      22.355947
# min      -1.000000
# 25%      12.000000
# 50%      20.000000
# 75%      31.000000
# max     304.000000

# %% [markdown]
# #### 종류별 대기오염도

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
dust.hist(bins=50, figsize=(20,15))
plt.show()
